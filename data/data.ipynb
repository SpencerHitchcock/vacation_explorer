# %%
#Location, start date, end date, 
import pandas as pd
import requests
import json
url = "http://eventful.com/oauth/authorize?oauth_token=ZXRjQzTcLvs84Dqh"
states = []

# %%
states = []
abr = []
file = "states.csv"
states_df = pd.read_csv(file)
# for i in states_df:
#     states.append(i['States]'.replace(" ","+"))
#     abr.appendend(i['Abr'])
def clean_state(state):
    return state.replace(" ","+")
states_df["State"] = states_df['State'].apply(clean_state)
states_df
# Out:
#                    State Abr
# 0                Alabama  AL
# 1                 Alaska  AK
# 2                Arizona  AZ
# 3               Arkansas  AR
# 4             California  CA
# 5               Colorado  CO
# 6            Connecticut  CT
# 7               Delaware  DE
# 8   District+of+Columbia  DC
# 9                Florida  FL
# 10               Georgia  GA
# 11                Hawaii  HI
# 12                 Idaho  ID
# 13              Illinois  IL
# 14               Indiana  IN
# 15                  Iowa  IA
# 16                Kansas  KS
# 17              Kentucky  KY
# 18             Louisiana  LA
# 19                 Maine  ME
# 20               Montana  MT
# 21              Nebraska  NE
# 22                Nevada  NV
# 23         New+Hampshire  NH
# 24            New+Jersey  NJ
# 25            New+Mexico  NM
# 26              New+York  NY
# 27        North+Carolina  NC
# 28          North+Dakota  ND
# 29                  Ohio  OH
# 30              Oklahoma  OK
# ...

# %%
event_title = []
city = []
start_time  = []
latitude = []
longitude = []
short_bio = []
going_count = []
state_name = []

for state in states_df["State"]:
    search_url = f"http://api.eventful.com/json/events/search?...&location={state}&date=future&sort_order=popularity&page_size=10&app_key=ZXRjQzTcLvs84Dqh"
    test = requests.get(search_url).json()
    items = test["events"]["event"]
    
    for item in items[:20]:
        event_title.append(item['title'])
        city.append(item['city_name'])
        state_name.append(item['region_name'])

        start_time.append(item['start_time'][:10])
        latitude.append(item['latitude'])
        longitude.append(item['longitude'])
        
#         if isinstance(item['performers']['performer'],(list,)):      
#             short_bio.append(item['performers']['performer'][0]['short_bio'])
#         else:
#             short_bio.append(item['performers']['performer']['short_bio'])
        going_count.append(item['going_count'])

# %%
events_df = pd.DataFrame({"Title":event_title,
                          "City": city,
                          "State": state_name,
                          "Start Time": start_time,
#                          "Latitude": latitude,
#                          "Longitude": longitude,
                          "# Going": going_count})
events_df['State'].value_counts()
# Out:
# Vermont                 10
# South Dakota            10
# Mississippi             10
# Alaska                  10
# North Carolina          10
# Pennsylvania            10
# New York                10
# Utah                    10
# New Hampshire           10
# Florida                 10
# Massachusetts           10
# California              10
# Michigan                10
# Missouri                10
# Louisiana               10
# Kentucky                10
# Arizona                 10
# Colorado                10
# Hawaii                  10
# Kansas                  10
# New Jersey              10
# Montana                 10
# Iowa                    10
# Arkansas                10
# West Virginia           10
# Delaware                10
# Nebraska                10
# Maine                   10
# Alabama                 10
# Wisconsin               10
# Illinois                10
# New Mexico              10
# Minnesota               10
# Nevada                  10
# ...

# %%
ustates
# Out:
#                    State  Count
# 0                Alabama     10
# 1                 Alaska     10
# 2                Arizona     10
# 3               Arkansas     10
# 4             California     10
# 5               Colorado     10
# 6            Connecticut     10
# 7               Delaware     10
# 8   District+of+Columbia     10
# 9                Florida     10
# 10               Georgia     10
# 11                Hawaii     10
# 12                 Idaho     10
# 13              Illinois     10
# 14               Indiana     10
# 15                  Iowa     10
# 16                Kansas     10
# 17              Kentucky     10
# 18             Louisiana     10
# 19                 Maine     10
# 20              Maryland     10
# 21         Massachusetts     10
# 22              Michigan     10
# 23             Minnesota     10
# 24           Mississippi     10
# 25              Missouri     10
# 26               Montana     10
# 27              Nebraska     10
# ...

# %%
events_df["State"] = events_df['State'].apply(clean_state)
ustates = events_df

ustates = ustates.groupby(['State']).size().reset_index(name='Count')
#ustates = pd.DataFrame(ustates)
#ustates.columns = ['States', 'Count']

# def abr_function();
#     if ustates['State'] == states_df['States']
#         ustates['Abr'] = states_df['Abr']

merge_df = ustates.merge(states_df,on='State')

merge_df
# Out:
#                    State  Count Abr
# 0                Alabama     10  AL
# 1                 Alaska     10  AK
# 2                Arizona     10  AZ
# 3               Arkansas     10  AR
# 4             California     10  CA
# 5               Colorado     10  CO
# 6            Connecticut     10  CT
# 7               Delaware     10  DE
# 8   District+of+Columbia     10  DC
# 9                Florida     10  FL
# 10               Georgia     10  GA
# 11                Hawaii     10  HI
# 12                 Idaho     10  ID
# 13              Illinois     10  IL
# 14               Indiana     10  IN
# 15                  Iowa     10  IA
# 16                Kansas     10  KS
# 17              Kentucky     10  KY
# 18             Louisiana     10  LA
# 19                 Maine     10  ME
# 20              Maryland     10  MD
# 21         Massachusetts     10  MA
# 22              Michigan     10  MI
# 23             Minnesota     10  MN
# 24           Mississippi     10  MS
# ...

# %%
def abr_function();
    if ustates['State'] == states_df['States']
        ustates['Abr'] = states_df['Abr']
# Out:
#   File "<ipython-input-37-47af3e21b33e>", line 1
#     def abr_function();
#                       ^
# SyntaxError: invalid syntax

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df = merge_df

for col in df.columns:
    df[col] = df[col].astype(str)

scl = [
    [0.0, 'rgb(242,240,247)'],
    [0.2, 'rgb(218,218,235)'],
    [0.4, 'rgb(188,189,220)'],
    [0.6, 'rgb(158,154,200)'],
    [0.8, 'rgb(117,107,177)'],
    [1.0, 'rgb(84,39,143)']
]


df['text'] = 'State: ' + df['State'] + '<br>' + \
df['Count'] + ' events'

data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = df['Abr'],
    z = df['Count'].astype(float),
    locationmode = 'USA-states',
    text = df['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Events")
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Events by state for specific date<br>(Hover for breakdown)'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'd3-cloropleth-map')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~SpencerHitchcock/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# C:\Users\spitc\Anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SpencerHitchcock/0.embed" height="525px" width="100%"></iframe>

# %%
len(test["events"]["event"])

# %%
search_url = f"http://api.eventful.com/json/events/search?...&location=washington+state&date=future&sort_order=popularity&page_size=10&app_key=ZXRjQzTcLvs84Dqh"
test = requests.get(search_url).json()
items = test["events"]["event"]
items
# Out:
# [{'watching_count': None,
#   'olson_path': 'America/Los_Angeles',
#   'calendar_count': None,
#   'comment_count': None,
#   'region_abbr': 'WA',
#   'postal_code': '98421',
#   'going_count': None,
#   'all_day': '0',
#   'latitude': '47.2372871',
#   'groups': None,
#   'url': 'http://seattle.eventful.com/events/michael-buble-/E0-001-119879305-0?utm_source=apis&utm_medium=apim&utm_campaign=apic',
#   'id': 'E0-001-119879305-0',
#   'privacy': '1',
#   'city_name': 'Tacoma',
#   'link_count': None,
#   'longitude': '-122.4260438',
#   'country_name': 'United States',
#   'country_abbr': 'USA',
#   'region_name': 'Washington',
#   'start_time': '2019-04-06 20:00:00',
#   'tz_id': None,
#   'description': None,
#   'modified': '2018-11-08 09:00:08',
#   'venue_display': '1',
#   'tz_country': None,
#   'performers': {'performer': {'creator': 'wbrecords',
#     'linker': 'evdb',
#     'name': 'Michael Bublé',
# ...
