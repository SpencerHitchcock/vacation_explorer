# %%
#Location, start date, end date, 
import pandas as pd
import requests
import json
url = "http://eventful.com/oauth/authorize?oauth_token=ZXRjQzTcLvs84Dqh"
states = []

# %%
states = []
abr = []
file = "states.csv"
states_df = pd.read_csv(file)
# for i in states_df:
#     states.append(i['States]'.replace(" ","+"))
#     abr.appendend(i['Abr'])
def clean_state(state):
    return state.replace(" ","+")
states_df["State"] = states_df['State'].apply(clean_state)
states_df
# Out:
#                    State Abr
# 0                Alabama  AL
# 1                 Alaska  AK
# 2                Arizona  AZ
# 3               Arkansas  AR
# 4             California  CA
# 5               Colorado  CO
# 6            Connecticut  CT
# 7               Delaware  DE
# 8   District+of+Columbia  DC
# 9                Florida  FL
# 10               Georgia  GA
# 11                Hawaii  HI
# 12                 Idaho  ID
# 13              Illinois  IL
# 14               Indiana  IN
# 15                  Iowa  IA
# 16                Kansas  KS
# 17              Kentucky  KY
# 18             Louisiana  LA
# 19                 Maine  ME
# 20               Montana  MT
# 21              Nebraska  NE
# 22                Nevada  NV
# 23         New+Hampshire  NH
# 24            New+Jersey  NJ
# 25            New+Mexico  NM
# 26              New+York  NY
# 27        North+Carolina  NC
# 28          North+Dakota  ND
# 29                  Ohio  OH
# 30              Oklahoma  OK
# 31                Oregon  OR
# 32              Maryland  MD
# 33         Massachusetts  MA
# 34              Michigan  MI
# 35             Minnesota  MN
# 36           Mississippi  MS
# 37              Missouri  MO
# 38          Pennsylvania  PA
# 39          Rhode+Island  RI
# 40        South+Carolina  SC
# 41          South+Dakota  SD
# 42             Tennessee  TN
# 43                 Texas  TX
# 44                  Utah  UT
# 45               Vermont  VT
# 46              Virginia  VA
# 47      Washington+State  WA
# 48         West+Virginia  WV
# 49             Wisconsin  WI
# 50               Wyoming  WY

# %%
event_title = []
city = []
start_time  = []
latitude = []
longitude = []
short_bio = []
going_count = []
state_name = []

for state in states_df["State"]:
    search_url = f"http://api.eventful.com/json/events/search?...&location={state}&date=future&sort_order=popularity&page_size=10&app_key=ZXRjQzTcLvs84Dqh"
    test = requests.get(search_url).json()
    items = test["events"]["event"]
    
    for item in items[:20]:
        event_title.append(item['title'])
        city.append(item['city_name'])
        state_name.append(item['region_name'])

        start_time.append(item['start_time'][:10])
        latitude.append(item['latitude'])
        longitude.append(item['longitude'])
        
#         if isinstance(item['performers']['performer'],(list,)):      
#             short_bio.append(item['performers']['performer'][0]['short_bio'])
#         else:
#             short_bio.append(item['performers']['performer']['short_bio'])
        going_count.append(item['going_count'])

# %%
events_df = pd.DataFrame({"Title":event_title,
                          "City": city,
                          "State": state_name,
                          "Start Time": start_time,
#                          "Latitude": latitude,
#                          "Longitude": longitude,
                          "# Going": going_count})
events_df['State'].value_counts()
# Out:
# New Jersey              12
# Texas                   10
# District of Columbia    10
# Arizona                 10
# Nebraska                10
# Alaska                  10
# Colorado                10
# Alabama                 10
# Idaho                   10
# South Carolina          10
# Minnesota               10
# Louisiana               10
# Missouri                10
# Indiana                 10
# Wyoming                 10
# Illinois                10
# Georgia                 10
# Michigan                10
# Kentucky                10
# North Dakota            10
# West Virginia           10
# Arkansas                10
# Massachusetts           10
# South Dakota            10
# Virginia                10
# Maryland                10
# New Hampshire           10
# Wisconsin               10
# Utah                    10
# Connecticut             10
# Nevada                  10
# Mississippi             10
# Delaware                10
# Florida                 10
# Washington              10
# Oklahoma                10
# New Mexico              10
# California              10
# North Carolina          10
# Hawaii                  10
# Vermont                 10
# Maine                   10
# Montana                 10
# Ohio                    10
# Rhode Island            10
# Tennessee               10
# Oregon                  10
# Kansas                  10
# Iowa                    10
# Pennsylvania            10
# New York                 8
# Name: State, dtype: int64

# %%
events_df['Start Time']
# Out:
# 0      2019-04-23
# 1      2019-04-23
# 2      2019-04-25
# 3      2019-04-27
# 4      2019-05-02
# 5      2019-05-03
# 6      2019-07-19
# 7      2019-08-22
# 8      2019-04-13
# 9      2019-04-10
# 10     2019-08-23
# 11     2019-08-02
# 12     2019-05-07
# 13     2019-05-08
# 14     2019-05-08
# 15     2019-05-07
# 16     2019-04-11
# 17     2019-04-20
# 18     2019-04-19
# 19     2019-04-20
# 20     2019-04-09
# 21     2019-04-28
# 22     2019-05-07
# 23     2019-09-21
# 24     2019-09-10
# 25     2019-08-31
# 26     2019-07-31
# 27     2019-11-16
# 28     2019-11-23
# 29     2019-08-04
#           ...
# 480    2019-10-26
# 481    2019-04-13
# 482    2019-05-04
# 483    2019-07-26
# 484    2019-09-27
# 485    2019-04-14
# 486    2019-04-16
# 487    2019-04-22
# 488    2019-04-12
# 489    2019-04-27
# 490    2019-05-02
# 491    2019-04-13
# 492    2019-04-20
# 493    2019-08-06
# 494    2019-10-04
# 495    2019-04-11
# 496    2019-04-16
# 497    2019-04-20
# 498    2019-04-20
# 499    2019-04-15
# 500    2019-07-20
# 501    2019-04-12
# 502    2019-07-21
# 503    2019-07-26
# 504    2019-07-19
# 505    2019-07-24
# 506    2019-07-14
# 507    2019-07-10
# 508    2019-07-12
# 509    2019-04-10
# Name: Start Time, Length: 510, dtype: object

# %%
events_df['Start Time'] = pd.to_datetime(events_df['Start Time'])


events_df['dow'] = events_df['Start Time'].dt.dayofweek
#df['weekday'] = df['Timestamp'].dt.dayofweek
events_df
# Out:
#                                                  Title          City  \
# 0                                        Jimmy Buffett  Orange Beach
# 1                                  The Doobie Brothers    Huntsville
# 2                                       Zac Brown Band    Tuscaloosa
# 3                                        Kenny Chesney  Orange Beach
# 4                                      Hillsong United    Birmingham
# 5      Carrie Underwood, Maddie and Tae & Runaway June    Birmingham
# 6                                         Brad Paisley        Pelham
# 7                                         Brad Paisley  Orange Beach
# 8                                                 Kiss    Birmingham
# 9                                  Death Cab For Cutie    Birmingham
# 10                                           Shinedown        Palmer
# 11                                         Norah Jones     Anchorage
# 12                              Garden Brothers Circus     Fairbanks
# 13                              Garden Brothers Circus     Fairbanks
# 14                              Garden Brothers Circus     Fairbanks
# 15                             Monty Python's Spamalot     Anchorage
# 16                                           Zeds Dead     Anchorage
# 17   An Evening of Smooth Jazz with Peter White, Jo...     Anchorage
# 18              Solid As A Rock Fighting Championships     Fairbanks
# 19                                   Wrestlepro Alaska     Anchorage
# 20                                              Wicked         Tempe
# 21                                     John Mellencamp        Tucson
# 22                                  The Rolling Stones      Glendale
# 23                                       Mark Knopfler       Phoenix
# 24                                          John Mayer       Phoenix
# 25                              Korn & Alice In Chains       Phoenix
# 26                   Third Eye Blind & Jimmy Eat World       Phoenix
# 27                    The Black Keys with Modest Mouse       Phoenix
# 28                                                Cher      Glendale
# 29                                  Slipknot - Ak-Chin       Phoenix
# ..                                                 ...           ...
# 480                                      Jamey Johnson  Charles Town
# 481                                        Jeff Dunham    Huntington
# 482                                       Justin Moore    Huntington
# 483                                        Cheap Trick  Charles Town
# 484                          Disturbed: Evolution Tour    Huntington
# 485                                    Doobie Brothers    Charleston
# 486                                      David Sedaris     Lewisburg
# 487                              Chicago - The Musical    Morgantown
# 488                                       Travis Tritt    Charleston
# 489                                   Rick Springfield    Charleston
# 490                                               Pink     Milwaukee
# 491                                    John Mellencamp     Green Bay
# 492                                    Alice In Chains     Milwaukee
# 493                                         John Mayer     Milwaukee
# 494                   The Black Keys with Modest Mouse     Milwaukee
# 495                                    Three Dog Night      Appleton
# 496                     B - The Underwater Bubble Show      Appleton
# 497                                       Black Violin     Milwaukee
# 498                                           Godsmack     Milwaukee
# 499                                      Ariana Grande     Milwaukee
# 500             Cheyenne Frontier Days - Rascal Flatts      Cheyenne
# 501                                        Steel Pulse       Jackson
# 502               Cheyenne Frontier Days - Josh Turner      Cheyenne
# 503               Cheyenne Frontier Days - Keith Urban      Cheyenne
# 504           Cheyenne Frontier Days - Lady Antebellum      Cheyenne
# 505           Cheyenne Frontier Days - Miranda Lambert      Cheyenne
# 506                                        Norah Jones      Cheyenne
# 507                                 The Avett Brothers       Jackson
# 508                                        Jenny Lewis       Jackson
# 509                                       Old Dominion        Casper
#
#              State Start Time # Going  dow
# 0          Alabama 2019-04-23    None    1
# 1          Alabama 2019-04-23    None    1
# 2          Alabama 2019-04-25    None    3
# 3          Alabama 2019-04-27    None    5
# 4          Alabama 2019-05-02    None    3
# 5          Alabama 2019-05-03    None    4
# 6          Alabama 2019-07-19    None    4
# 7          Alabama 2019-08-22    None    3
# 8          Alabama 2019-04-13    None    5
# 9          Alabama 2019-04-10    None    2
# 10          Alaska 2019-08-23    None    4
# 11          Alaska 2019-08-02    None    4
# 12          Alaska 2019-05-07    None    1
# 13          Alaska 2019-05-08    None    2
# 14          Alaska 2019-05-08    None    2
# 15          Alaska 2019-05-07    None    1
# 16          Alaska 2019-04-11    None    3
# 17          Alaska 2019-04-20    None    5
# 18          Alaska 2019-04-19    None    4
# 19          Alaska 2019-04-20    None    5
# 20         Arizona 2019-04-09    None    1
# 21         Arizona 2019-04-28    None    6
# 22         Arizona 2019-05-07    None    1
# 23         Arizona 2019-09-21    None    5
# 24         Arizona 2019-09-10    None    1
# 25         Arizona 2019-08-31    None    5
# 26         Arizona 2019-07-31    None    2
# 27         Arizona 2019-11-16    None    5
# 28         Arizona 2019-11-23    None    5
# 29         Arizona 2019-08-04    None    6
# ..             ...        ...     ...  ...
# 480  West Virginia 2019-10-26    None    5
# 481  West Virginia 2019-04-13    None    5
# 482  West Virginia 2019-05-04    None    5
# 483  West Virginia 2019-07-26    None    4
# 484  West Virginia 2019-09-27    None    4
# 485  West Virginia 2019-04-14    None    6
# 486  West Virginia 2019-04-16    None    1
# 487  West Virginia 2019-04-22    None    0
# 488  West Virginia 2019-04-12    None    4
# 489  West Virginia 2019-04-27    None    5
# 490      Wisconsin 2019-05-02    None    3
# 491      Wisconsin 2019-04-13    None    5
# 492      Wisconsin 2019-04-20    None    5
# 493      Wisconsin 2019-08-06    None    1
# 494      Wisconsin 2019-10-04    None    4
# 495      Wisconsin 2019-04-11    None    3
# 496      Wisconsin 2019-04-16    None    1
# 497      Wisconsin 2019-04-20    None    5
# 498      Wisconsin 2019-04-20    None    5
# 499      Wisconsin 2019-04-15    None    0
# 500        Wyoming 2019-07-20    None    5
# 501        Wyoming 2019-04-12    None    4
# 502        Wyoming 2019-07-21    None    6
# 503        Wyoming 2019-07-26    None    4
# 504        Wyoming 2019-07-19    None    4
# 505        Wyoming 2019-07-24    None    2
# 506        Wyoming 2019-07-14    None    6
# 507        Wyoming 2019-07-10    None    2
# 508        Wyoming 2019-07-12    None    4
# 509        Wyoming 2019-04-10    None    2
#
# [510 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.tools as tls

events_df['dow'].value_counts()
week_df = events_df[['Start Time', 'dow']]
#week_df
def set_value(row_number, assigned_value):
    return assigned_value[row_number]
week_dict = {0 : 'Monday', 1 : 'Tuesday', 2 : 'Wednesday', 3 : 'Thursday', 4 : 'Friday', 5 : 'Saturday', 6 : 'Sunday'}



week_df['spelled'] = week_df['dow'].apply(set_value, args =(week_dict, ))
week_df = week_df.groupby('spelled', as_index=False).count()
week_df

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
#week_df["State"] = week_df['State'].apply(clean_state)
#ustates = events_df
#ustates = ustates.groupby(['State']).size().reset_index(name='Count')
#ustates = pd.DataFrame(ustates)
#ustates.columns = ['States', 'Count']

# def abr_function();
#     if ustates['State'] == states_df['States']
#         ustates['Abr'] = states_df['Abr']

#week_df.spelled.value_counts().reindex(days, fill_value=0).plot.bar()

# new_df

week_df['spelled'] = pd.Categorical(week_df['spelled'], categories=days, ordered=True)
week_df = week_df.sort_values('spelled')
week_df
    

pd.options.mode.chained_assignment = None 
bar_graph = [go.Bar(
             x=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
             y=week_df['dow']
     )]
py.iplot(bar_graph, filename='basic-bar')

# hold_red = red_blend
# hold_red = hold_red.rename(index=str, columns={'Points': 'Count'})
# hold_red = hold_red.loc[:, ["Country", "Count"]]
# hold_red = hold_red.groupby(['Country']).count()
# reduced_red = red_blend.loc[:, ["Country", "Points"]]
# ordered_red = reduced_red.groupby(['Country']).mean()
# ordered_red = ordered_red.merge(hold_red, on='Country')
# ordered_red = ordered_red.loc[(ordered_red['Count'] > 5)]
# ordered_red =  ordered_red.sort_values(by=['Points'], ascending=False)
# ordered_red.head(10)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SpencerHitchcock/2.embed" height="525px" width="100%"></iframe>

# %%
events_df["State"] = events_df['State'].apply(clean_state)
ustates = events_df

ustates = ustates.groupby(['State']).size().reset_index(name='Count')
#ustates = pd.DataFrame(ustates)
#ustates.columns = ['States', 'Count']

# def abr_function();
#     if ustates['State'] == states_df['States']
#         ustates['Abr'] = states_df['Abr']

states.append(i['States]'.replace(" ","+"))

merge_df = ustates.merge(states_df,on='State')

merge_df
# Out:
#   File "<ipython-input-7-30f42d34570f>", line 12
#     states.append(i['States]'.replace(" ","+"))
#                                               ^
# SyntaxError: invalid syntax

# %%
merge_df

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df = merge_df

for col in df.columns:
    df[col] = df[col].astype(str)

scl = [
    [0.0, 'rgb(242,240,247)'],
    [0.2, 'rgb(218,218,235)'],
    [0.4, 'rgb(188,189,220)'],
    [0.6, 'rgb(158,154,200)'],
    [0.8, 'rgb(117,107,177)'],
    [1.0, 'rgb(84,39,143)']
]


df['text'] = 'State: ' + df['State'] + '<br>' + \
df['Count'] + ' events'

data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = df['Abr'],
    z = df['Count'].astype(float),
    locationmode = 'USA-states',
    text = df['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Events")
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Events by state for specific date<br>(Hover for breakdown)'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'd3-cloropleth-map')

# %%
len(test["events"]["event"])

# %%
search_url = f"http://api.eventful.com/json/events/search?...&location=washington+state&date=future&sort_order=popularity&page_size=10&app_key=ZXRjQzTcLvs84Dqh"
test = requests.get(search_url).json()
items = test["events"]["event"]
items
