# %%
import requests
import json
import pandas as pd

states_csv = "state_table.csv"
states_df = pd.read_csv(states_csv)

#def function to search API for a state + date
def get_count(state,start_date,end_date):
    search_url = f"http://api.eventful.com/json/events/search?&location={state}&date=2019040800-2019040900&sort_order=popularity&count_only=True&app_key=ZXRjQzTcLvs84Dqh"
    events = requests.get(search_url).json()
    return events['total_items']

# %%
states_df = states_df.drop(columns="Count")

# %%
start_date = '2019040800'
end_date = '2019040900'

states_df["Count"] = get_count(states_df["State"],start_date,end_date)

# %%
states_df
# Out:
#                State Abr Count
# 0            Alabama  AL  3128
# 1             Alaska  AK  3128
# 2            Arizona  AZ  3128
# 3           Arkansas  AR  3128
# 4         California  CA  3128
# 5           Colorado  CO  3128
# 6        Connecticut  CT  3128
# 7           Delaware  DE  3128
# 8            Florida  FL  3128
# 9            Georgia  GA  3128
# 10            Hawaii  HI  3128
# 11             Idaho  ID  3128
# 12          Illinois  IL  3128
# 13           Indiana  IN  3128
# 14              Iowa  IA  3128
# 15            Kansas  KS  3128
# 16          Kentucky  KY  3128
# 17         Louisiana  LA  3128
# 18             Maine  ME  3128
# 19          Maryland  MD  3128
# 20     Massachusetts  MA  3128
# 21          Michigan  MI  3128
# 22         Minnesota  MN  3128
# 23       Mississippi  MS  3128
# 24          Missouri  MO  3128
# 25           Montana  MT  3128
# 26          Nebraska  NE  3128
# 27            Nevada  NV  3128
# 28     New Hampshire  NH  3128
# ...
